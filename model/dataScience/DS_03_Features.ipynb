# %% [markdown]
# # Data Science 01: Feature Engineering

# %% [markdown]
# <h3 id="import_data">1. Import Data</h3>

# %% [markdown]
# Import libraries:

# %%
# install libraries
#%pip instal pandas
#%pip install numpy

# SciPy is a free and open-source Python library used for scientific computing and technical computing.
# It is a collection of mathematical algorithms and convenience functions built on the NumPy extension of Python.
#%pip install scipy

#%pip install seaborn

# %%
import pandas as pd
import numpy as np

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# Load the data and store it in dataframe `df`:

# %%
path='../../data/raw/exploration_timelaps.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    id type_brick time_start time_verif time_dest  time_end  time_start_sec  \
# 0   1     CORNER   13:52:18   13:52:24  13:52:42  13:52:58           49938
# 1   2       HALF   13:52:58   13:53:02  13:53:18  13:53:36           49978
# 2   3      BASIC   13:53:36   13:55:20  13:55:44  13:56:00           50016
# 3   4      BASIC   13:56:00   13:56:06  13:56:20  13:56:36           50160
# 4   5      BASIC   13:56:36   13:56:40  13:56:54  13:58:10           50196
#
#    time_verif_sec  time_dest_sec  time_end_sec  type  start_to_verif  \
# 0           49944          49962         49978     2               6
# 1           49982          49998         50016     3               4
# 2           50120          50144         50160     1             104
# 3           50166          50180         50196     1               6
# 4           50200          50214         50290     1               4
#
#    verif_to_dest  dest_to_end  total_time total_time_binned  brick_basic  \
# 0             18           16          40   Extremely short        False
# 1             16           18          38   Extremely short        False
# 2             24           16         144    Extremely long         True
# 3             14           16          36   Extremely short         True
# 4             14           76          94            Normal         True
#
#    brick_corner  brick_end  brick_half
# 0          True      False       False
# 1         False      False        True
# 2         False      False       False
# 3         False      False       False
# 4         False      False       False

# %% [markdown]
# <h3 id="pattern_visualization">2. Analyzing Individual Feature Patterns Using Visualization</h3>

# %% [markdown]
# Import visualization packages "Matplotlib" and "Seaborn". Don't forget about "%matplotlib inline" to plot in a Jupyter notebook.

# %%
#%pip install seaborn
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# <h4>How to choose the right visualization method?</h4>
# <p>When visualizing individual variables, it is important to first understand what type of variable you are dealing with. This will help us find the right visualization method for that variable.</p>

# %%
# list the data types for each column
print(df.dtypes)
# Out:
# id                   int64
# type_brick             str
# time_start             str
# time_verif             str
# time_dest              str
# time_end               str
# time_start_sec       int64
# time_verif_sec       int64
# time_dest_sec        int64
# time_end_sec         int64
# type                 int64
# start_to_verif       int64
# verif_to_dest        int64
# dest_to_end          int64
# total_time           int64
# total_time_binned      str
# brick_basic           bool
# brick_corner          bool
# brick_end             bool
# brick_half            bool
# dtype: object

# %% [markdown]
# For example, we can calculate the correlation between variables  of type "int64" or "float64" using the method "corr":

# %%
df[['type', 'start_to_verif', 'verif_to_dest', 'dest_to_end', 'total_time']].corr()
# Out:
#                     type  start_to_verif  verif_to_dest  dest_to_end  \
# type            1.000000        0.021289       0.184855     0.037412
# start_to_verif  0.021289        1.000000       0.136263    -0.032674
# verif_to_dest   0.184855        0.136263       1.000000     0.044277
# dest_to_end     0.037412       -0.032674       0.044277     1.000000
# total_time      0.097277        0.566009       0.419233     0.745773
#
#                 total_time
# type              0.097277
# start_to_verif    0.566009
# verif_to_dest     0.419233
# dest_to_end       0.745773
# total_time        1.000000

# %% [markdown]
# The diagonal elements are always one; we will study correlation more precisely Pearson correlation in-depth at the end of the notebook.

# %% [markdown]
# <h3>Continuous Numerical Variables:</h3>
#
# <p>Continuous numerical variables are variables that may contain any value within some range. They can be of type "int64" or "float64". A great way to visualize these variables is by using scatterplots with fitted lines.</p>
#
# <p>In order to start understanding the (linear) relationship between an individual variable and the price, we can use "regplot" which plots the scatterplot plus the fitted regression line for the data. This will be useful later on for visualizing the fit of the simple linear regression model as well. </p>

# %% [markdown]
# <h4>Positive Linear Relationship</h4>

# %% [markdown]
# Let's find the scatterplot of "total_time" and "start_to_verif".

# %%
# Engine size as potential predictor variable of price
sns.regplot(x="total_time", y="start_to_verif", data=df)
plt.ylim(0,)
# Out:
# (0.0, 109.18908628711719)

# %% [markdown]
# <h3>Categorical Variables</h3>
#
# <p>These are variables that describe a 'characteristic' of a data unit, and are selected from a small group of categories. The categorical variables can have the type "object" or "int64". A good way to visualize categorical variables is by using boxplots.</p>

# %% [markdown]
# Let's look at the relationship between "type" and "total_time".

# %%
sns.boxplot(x='type_brick', y="total_time", data=df)
# Out:
# <Axes: xlabel='type_brick', ylabel='total_time'>

# %% [markdown]
# <h3 id="discriptive_statistics">3. Descriptive Statistical Analysis</h3>

# %% [markdown]
# <p>The <b>describe</b> function automatically computes basic statistics for all continuous variables. Any NaN values are automatically skipped in these statistics.</p>
#
# This will show:
# <ul>
#     <li>the count of that variable</li>
#     <li>the mean</li>
#     <li>the standard deviation (std)</li>
#     <li>the minimum value</li>
#     <li>the IQR (Interquartile Range: 25%, 50% and 75%)</li>
#     <li>the maximum value</li>
# <ul>

# %%
df.describe()
# Out:
#                id  time_start_sec  time_verif_sec  time_dest_sec  \
# count  133.000000      133.000000      133.000000     133.000000
# mean    68.954887    53178.037594    53187.270677   53202.150376
# std     39.578243     2889.561303     2888.835306    2887.340428
# min      1.000000    48679.000000    48685.000000   48703.000000
# 25%     36.000000    50544.000000    50552.000000   50569.000000
# 50%     69.000000    51755.000000    51765.000000   51776.000000
# 75%    103.000000    55839.000000    55845.000000   55863.000000
# max    137.000000    57449.000000    57466.000000   57473.000000
#
#        time_end_sec        type  start_to_verif  verif_to_dest  dest_to_end  \
# count    133.000000  133.000000      133.000000     133.000000   133.000000
# mean   53222.330827    1.255639        9.233083      14.879699    20.180451
# std     2883.705657    0.745229        9.108677       5.174292    12.462571
# min    48725.000000    1.000000        4.000000       7.000000     7.000000
# 25%    50591.000000    1.000000        6.000000      12.000000    14.000000
# 50%    51791.000000    1.000000        8.000000      14.000000    16.000000
# 75%    55894.000000    1.000000        9.000000      16.000000    22.000000
# max    57483.000000    4.000000      104.000000      58.000000    80.000000
#
#        total_time
# count  133.000000
# mean    44.293233
# std     16.619075
# min     28.000000
# 25%     36.000000
# 50%     40.000000
# 75%     46.000000
# max    144.000000

# %% [markdown]
# <h4>Value Counts</h4>

# %% [markdown]
# <p>Value counts is a good way of understanding how many units of each characteristic/variable we have. We can apply the "value_counts" method on the column "type_brick". </p>

# %%
df['type_brick'].value_counts()
# Out:
# type_brick
# BASIC     117
# HALF        6
# END         6
# CORNER      4
# Name: count, dtype: int64

# %% [markdown]
# We can convert the series to a dataframe as follows:

# %%
df['type_brick'].value_counts().to_frame()
# Out:
#             count
# type_brick
# BASIC         117
# HALF            6
# END             6
# CORNER          4

# %% [markdown]
# Let's repeat the above steps but save the results to the dataframe "bricks" and rename the column 'count' to 'value_counts'.

# %%
bricks = df['type_brick'].value_counts().to_frame()
bricks.rename(columns={'count': 'value_counts'}, inplace=True)
bricks
# Out:
#             value_counts
# type_brick
# BASIC                117
# HALF                   6
# END                    6
# CORNER                 4

# %% [markdown]
# <h3 id="basic_grouping">4. Basics of Grouping</h3>

# %% [markdown]
# <p>The "groupby" method groups data by different categories. The data is grouped based on one or several variables, and analysis is performed on the individual groups.</p>
#
# <p>For example, let's group by the variable "type_brick". We see that there are 3 different categories of bricks.</p>

# %%
df['type_brick'].unique()
# Out:
# <StringArray>
# ['CORNER', 'HALF', 'BASIC', 'END']
# Length: 4, dtype: str

# %% [markdown]
# <p>If we want to know, on average, which type of brick is most valuable, we can group "type_brick" and then average them.</p>
#
# <p>We can select the columns 'type_brick' and 'total_time', then assign it to the variable "df_group_one".</p>

# %%
df_group_one = df[['type_brick', 'total_time']]
df_group_one
# Out:
#     type_brick  total_time
# 0       CORNER          40
# 1         HALF          38
# 2        BASIC         144
# 3        BASIC          36
# 4        BASIC          94
# ..         ...         ...
# 128      BASIC          30
# 129      BASIC          31
# 130      BASIC          37
# 131      BASIC          28
# 132      BASIC          34
#
# [133 rows x 2 columns]

# %% [markdown]
# We can then calculate the average time for each of the different categories of data.

# %%
# grouping results
df_group_one = df_group_one.groupby(['type_brick'], as_index=False).mean()
df_group_one
# Out:
#   type_brick  total_time
# 0      BASIC   43.957265
# 1     CORNER   40.000000
# 2        END   54.833333
# 3       HALF   43.166667

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# <p>The main question we want to answer in this module is, "What are the main characteristics which have the most impact on the time cycle?".</p>
#
# <p>To get a better measure of the important characteristics, we look at the correlation of these variables</p>

# %% [markdown]
# <h3 id="correlation_causation">5. Correlation and Causation</h3>

# %% [markdown]
# <p><b>Correlation</b>: a measure of the extent of interdependence between variables.</p>
#
# <p><b>Causation</b>: the relationship between cause and effect between two variables.</p>

# %% [markdown]
# <p><b>Pearson Correlation</b></p>
# <p>The Pearson Correlation measures the linear dependence between two variables X and Y.</p>
# <p>The resulting coefficient is a value between -1 and 1 inclusive, where:</p>
# <ul>
#     <li><b>1</b>: Perfect positive linear correlation.</li>
#     <li><b>0</b>: No linear correlation, the two variables most likely do not affect each other.</li>
#     <li><b>-1</b>: Perfect negative linear correlation.</li>
# </ul>

# %% [markdown]
# <p>Pearson Correlation is the default method of the function "corr". Like before, we can calculate the Pearson Correlation of the of the 'int64' or 'float64'  variables.</p>

# %%
corr = df[['type', 'start_to_verif', 'verif_to_dest', 'dest_to_end', 'total_time']].corr()
corr
# Out:
#                     type  start_to_verif  verif_to_dest  dest_to_end  \
# type            1.000000        0.021289       0.184855     0.037412
# start_to_verif  0.021289        1.000000       0.136263    -0.032674
# verif_to_dest   0.184855        0.136263       1.000000     0.044277
# dest_to_end     0.037412       -0.032674       0.044277     1.000000
# total_time      0.097277        0.566009       0.419233     0.745773
#
#                 total_time
# type              0.097277
# start_to_verif    0.566009
# verif_to_dest     0.419233
# dest_to_end       0.745773
# total_time        1.000000

# %%
sns.set_theme(style="white")

plt.figure(figsize=(8, 6))
sns.heatmap(
    corr,
    annot=True,
    cmap="RdBu_r",
    center=0,
    linewidths=0.5
)
# Out:
# <Axes: >

# %% [markdown]
# Sometimes we would like to know the significant of the correlation estimate.

# %% [markdown]
# <b>P-value</b>
# <p>What is this P-value? The P-value is the probability value that the correlation between these two variables is statistically significant. Normally, we choose a significance level of 0.05, which means that we are 95% confident that the correlation between the variables is significant.</p>
#
# By convention, when the
# <ul>
#     <li>p-value is < 0.001: we say there is strong evidence that the correlation is significant.</li>
#     <li>the p-value is < 0.05: there is moderate evidence that the correlation is significant.</li>
#     <li>the p-value is < 0.1: there is weak evidence that the correlation is significant.</li>
#     <li>the p-value is > 0.1: there is no evidence that the correlation is significant.</li>
# </ul>

# %% [markdown]
#  We can obtain this information using  "stats" module in the "scipy"  library.

# %%
#%pip install scipy
from scipy import stats

# %% [markdown]
# <h4>Type of bricks vs. Total_time</h4>

# %% [markdown]
# Let's calculate the  Pearson Correlation Coefficient and P-value of 'type_brick' and 'total_time'.

# %%
pearson_coef, p_value = stats.pearsonr(df['type'], df['total_time'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.0972767279496189  with a P-value of P = 0.26532017553000314

# %% [markdown]
# <p>Since the p-value is < 0.001, the correlation between type of brick and total time is statistically significant, and the linear relationship is moderately strong.</p>

# %% [markdown]
# <h3 id="anova">6. ANOVA</h3>

# %% [markdown]
# <h4>ANOVA: Analysis of Variance (Analýza rozptylu)</h4>
# <p>The Analysis of Variance  (ANOVA) is a statistical method used to test whether there are significant differences between the means of two or more groups. ANOVA returns two parameters:</p>
#
# <p><b>F-test score</b>: ANOVA assumes the means of all groups are the same, calculates how much the actual means deviate from the assumption, and reports it as the F-test score. A larger score means there is a larger difference between the means.</p>
#
# <p><b>P-value</b>:  P-value tells how statistically significant our calculated score value is.</p>
#
# <p>If our price variable is strongly correlated with the variable we are analyzing, we expect ANOVA to return a sizeable F-test score and a small p-value.</p>

# %% [markdown]
# <h4>Drive Wheels</h4>

# %% [markdown]
# <p>Since ANOVA analyzes the difference between different groups of the same variable, the groupby function will come in handy. Because the ANOVA algorithm averages the data automatically, we do not need to take the average before hand.</p>
#
# <p>To see if different types of 'type_brick' impact  'total_time', we group the data.</p>

# %%
grouped_test = df[['type_brick', 'total_time']].groupby('type_brick')
grouped_test.head()
# Out:
#     type_brick  total_time
# 0       CORNER          40
# 1         HALF          38
# 2        BASIC         144
# 3        BASIC          36
# 4        BASIC          94
# 5        BASIC          36
# 6        BASIC          32
# 20         END          46
# 33        HALF          36
# 34      CORNER          38
# 35        HALF          44
# 50         END         114
# 51         END          38
# 68      CORNER          44
# 69        HALF          56
# 86         END          54
# 100       HALF          35
# 101     CORNER          38
# 117        END          41

# %%
grouped_test.get_group('BASIC')['total_time']
# Out:
# 2      144
# 3       36
# 4       94
# 5       36
# 6       32
#       ...
# 128     30
# 129     31
# 130     37
# 131     28
# 132     34
# Name: total_time, Length: 117, dtype: int64

# %% [markdown]
# #### BASIC and HALF

# %%
f_val, p_val = stats.f_oneway(grouped_test.get_group('BASIC')['total_time'], grouped_test.get_group('HALF')['total_time'])

print( "ANOVA results: F=", f_val, ", P =", p_val )
# Out:
# ANOVA results: F= 0.013806698920399143 , P = 0.9066571527764483

# %% [markdown]
# We notice that ANOVA for the categories `BASIC` and `HALF` yields a high p-value > 0.1, so the calculated F-test score is not very statistically significant. This suggests we can't reject the assumption that the means of these two groups are the same, or, in other words, we can't conclude the difference in correlation to be significant.

# %%
df
# Out:
#       id type_brick time_start time_verif time_dest  time_end  time_start_sec  \
# 0      1     CORNER   13:52:18   13:52:24  13:52:42  13:52:58           49938
# 1      2       HALF   13:52:58   13:53:02  13:53:18  13:53:36           49978
# 2      3      BASIC   13:53:36   13:55:20  13:55:44  13:56:00           50016
# 3      4      BASIC   13:56:00   13:56:06  13:56:20  13:56:36           50160
# 4      5      BASIC   13:56:36   13:56:40  13:56:54  13:58:10           50196
# ..   ...        ...        ...        ...       ...       ...             ...
# 128  132      BASIC   15:54:56   15:55:07  15:55:15  15:55:26           57296
# 129  133      BASIC   15:55:26   15:55:38  15:55:45  15:55:57           57326
# 130  134      BASIC   15:55:57   15:56:07  15:56:15  15:56:34           57357
# 131  135      BASIC   15:56:34   15:56:43  15:56:51  15:57:02           57394
# 132  137      BASIC   15:57:29   15:57:46  15:57:53  15:58:03           57449
#
#      time_verif_sec  time_dest_sec  time_end_sec  type  start_to_verif  \
# 0             49944          49962         49978     2               6
# 1             49982          49998         50016     3               4
# 2             50120          50144         50160     1             104
# 3             50166          50180         50196     1               6
# 4             50200          50214         50290     1               4
# ..              ...            ...           ...   ...             ...
# 128           57307          57315         57326     1              11
# 129           57338          57345         57357     1              12
# 130           57367          57375         57394     1              10
# 131           57403          57411         57422     1               9
# 132           57466          57473         57483     1              17
#
#      verif_to_dest  dest_to_end  total_time total_time_binned  brick_basic  \
# 0               18           16          40   Extremely short        False
# 1               16           18          38   Extremely short        False
# 2               24           16         144    Extremely long         True
# 3               14           16          36   Extremely short         True
# 4               14           76          94            Normal         True
# ..             ...          ...         ...               ...          ...
# 128              8           11          30   Extremely short         True
# 129              7           12          31   Extremely short         True
# 130              8           19          37   Extremely short         True
# 131              8           11          28   Extremely short         True
# 132              7           10          34   Extremely short         True
#
#      brick_corner  brick_end  brick_half
# 0            True      False       False
# 1           False      False        True
# 2           False      False       False
# 3           False      False       False
# 4           False      False       False
# ..            ...        ...         ...
# 128         False      False       False
# 129         False      False       False
# 130         False      False       False
# 131         False      False       False
# 132         False      False       False
#
# [133 rows x 20 columns]

# %% [markdown]
# <h3>Conclusion: Important Variables</h3>

# %% [markdown]
# <p>We now have a better idea of what our data looks like and which variables are important to take into account when predicting the time of cycle. We have narrowed it down to the following variables:</p>
#
# Continuous numerical variables:
# <ul>
#     <li>total_time</li>
#     <li>start_to_verif</li>
#     <li>verif_to_dest</li>
#     <li>dest_to_end</li>
# </ul>
#
#
# <p>As we now move into building machine learning models to automate our analysis, feeding the model with variables that meaningfully affect our target variable will improve our model's prediction performance.</p>

# %% [markdown]
# # Save ready Raw dataset to the new csv:

# %%
df_ready = df[['id', 'type_brick', 'type', 'start_to_verif', 'verif_to_dest', 'dest_to_end', 'total_time']]

# %%
df_ready.to_csv('../../data/raw/ready_timelaps.csv', index=False)

# %% [markdown]
# #### Author/Date/Organization

# %% [markdown]
# Vjaceslav Usmanov, CTU in Prague

# %% [markdown]
# ###### Change Log
#
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2026-01-21 | 1.1 | Vjaceslav Usmanov| added DS_03_Features.ipynb |
# | 2026-02-12 | 1.2 | Vjaceslav Usmanov| changed DS_03_Features.ipynb |
